# %% [markdown]
# <a href="https://colab.research.google.com/github/Yewon9/OpenCV_AIRLab/blob/main/diff_absolute.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import numpy as np, cv2

# %%
#연산에 필요한 영상을 읽고 그레이 스케일로 변환
img1 = cv2.imread('robot_arm1.jpg')
img2 = cv2.imread('robot_arm2.jpg')
img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
#두 영상의 절대 값 차 연산
diff = cv2.absdiff(img1_gray, img2_gray)

# %%
#차 영상을 극대화하기 위해 스레시 홀드 처리 및 컬러로 변환
_, diff = cv2.threshold(diff, 1, 255, cv2.THRESH_BINARY)
diff_red = cv2.cvtColor(diff, cv2.COLOR_GRAY2BGR)
diff_red[:,:,2] = 0

# %%
#두 번째 이미지에 변화 부분 표시
spot = cv2.bitwise_xor(img2, diff_red)

# %%
#결과 영상 출력
cv2_imshow(img1)
cv2_imshow(img2)
cv2_imshow(diff)
cv2_imshow(spot)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F41EEEC68D0>
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F41EEEC6250>
# <PIL.Image.Image image mode=L size=480x320 at 0x7F41EEEC60D0>
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F41EEEBAE50>
