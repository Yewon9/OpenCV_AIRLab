# %% [markdown]
# <a href="https://colab.research.google.com/github/Yewon9/OpenCV_AIRLab/blob/main/scale_resize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('fish.jpg')
height, width = img.shape[:2]

# %%
#크기 지정으로 축소
dst1 = cv2.resize(img, (int(width*0.5), int(height*0.5)), interpolation = cv2.INTER_AREA)

# %%
#배율 지정으로 확대
dst2 = cv2.resize(img, None, None, 2, 2, cv2.INTER_CUBIC)
#결과 출력
cv2_imshow(img)
cv2_imshow(dst1)
cv2_imshow(dst2)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE12944CD90>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FE12944C750>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FE131E0B650>
