# %% [markdown]
# <a href="https://colab.research.google.com/github/Yewon9/OpenCV_AIRLab/blob/main/histo_gray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
import numpy as numpy
import matplotlib.pylab as plt

# %%
#이미지를 그레이 스케일로 읽기 및 출력하기
img = cv2.imread('mountain.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x7F9E062C21D0>

# %%
#히스토그램 계산 및 그리기
hist = cv2.calcHist([img], [0], None, [256], [0,256])
plt.plot(hist)

# %%
print(hist.shape)
print(hist.sum(), img.shape)
plt.show()
# Out:
# (256, 1)
# 270000.0 (450, 600, 3)
