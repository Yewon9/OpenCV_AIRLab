# %% [markdown]
# <a href="https://colab.research.google.com/github/Yewon9/OpenCV_AIRLab/blob/main/edge_roberts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('sudoku.jpg')

# %%
#로버츠 커널 생성
gx_kernel = np.array([[1,0], [0,-1]])
gy_kernel = np.array([[0,1], [-1,0]])

# %%
#커널 적용
edge_gx = cv2.filter2D(img, -1, gx_kernel)
edge_gy = cv2.filter2D(img, -1, gy_kernel)

# %%
#결과 출력
merged = np.hstack((img, edge_gx, edge_gy, edge_gx + edge_gy))
cv2_imshow(merged)
# Out:
# <PIL.Image.Image image mode=RGB size=896x291 at 0x7F5EED254AD0>
