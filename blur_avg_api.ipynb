# %% [markdown]
# <a href="https://colab.research.google.com/github/Yewon9/OpenCV_AIRLab/blob/main/blur_avg_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
import numpy as np

# %%
file_name = 'taekwonv1.jpg'
img = cv2.imread(file_name)

# %%
#blur() 함수로 블러링
blur1 = cv2.blur(img, (10,10))
#boxFilter() 함수로 블러링 적용
blur2 = cv2.boxFilter(img, -1, (10,10))

# %%
#결과 출력
merged = np.hstack((img, blur1, blur2))
cv2_imshow(merged)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x444 at 0x7F495D5FC410>
