# %% [markdown]
# <a href="https://colab.research.google.com/github/Yewon9/OpenCV_AIRLab/blob/main/rotate_getmatrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread('fish.jpg')
rows, cols = img.shape[0:2]

# %%
#회전을 위한 변환행렬 구하기
#회전 축: 중앙, 각도: 45, 배율: 0.5
m45 = cv2.getRotationMatrix2D((cols/2, rows/2), 45, 0.5)
#회전 축: 중앙, 각도: 90, 배율: 1.5
m90 = cv2.getRotationMatrix2D((cols/2, rows/2), 90, 1.5)

# %%
#변환행렬 적용
img45 = cv2.warpAffine(img, m45, (cols, rows))
img90 = cv2.warpAffine(img, m90, (cols, rows))

# %%
#결과 출력
cv2_imshow(img)
cv2_imshow(img45)
cv2_imshow(img90)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F62D1AA4690>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F62D1A90B90>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F62D1A2DDD0>
